# %% [markdown]
# <a href="https://colab.research.google.com/github/lnsc/datasetrandom/blob/master/WCPRUEBA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import io
import requests
url="https://raw.githubusercontent.com/lnsc/datasetrandom/master/data.csv"
s=requests.get(url).content
c=pd.read_csv(io.StringIO(s.decode('utf-8')))

# %%
import numpy as np
from os import path
from PIL import Image
import os
os.getcwd()
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

# %%
text = c.a[1]
text
# Out:
# 'enix,Quetzalcoatl,Dragon,HombreLobo,angeles,Kraken,Demonio,Vampiro,Nian,Elfos,Sirena,Esfinge,Chupacabras,Bruja,Wendigo,Jinn,Fauno,SunWukong,Zombie,Fantasma,Oni,Nagas,Extraterrestre,Trol,Llorona,Momia,Trasgo,Duende,Orco,Tengu,Quimera,Enano,Hidra,Grifo,Hipocampo,Quimera,Minotauro,Banshe,Unicornio,Kyubi,Golem,Lamia,Ciclope,Basilisco,Arpia,Centauro,Hada,Triton'

# %%
#Guardando la imagen
wordcloud.to_file("WordCloud1.png")

# %%
def upload_files():
  from google.colab import files
  uploaded = files.upload()
  for k, v in uploaded.items():
    open(k, 'wb').write(v)
  return list(uploaded.keys())
upload_files()
# Out:
#      <input type="file" id="files-b575478f-30a8-4366-b6c4-0c3e29568421" name="files[]" multiple disabled />
#      <output id="result-b575478f-30a8-4366-b6c4-0c3e29568421">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving hada.png to hada (1).png
# ['hada.png']

# %%
mask = np.array(Image.open("hada.png"))

# %%
def generate_wordcloud(words, mask):
    word_cloud = WordCloud(width = 512, height = 512, background_color='white',mode='RGBA', stopwords=STOPWORDS,max_words=1000, mask=mask).generate(words)
    #plt.figure(figsize=(10,8),facecolor = 'white', edgecolor='blue')
    image_colors=ImageColorGenerator(mask)
    plt.figure(figsize=(10,8))
    plt.imshow(word_cloud.recolor(color_func=image_colors),interpolation="bilinear")
    plt.axis('off')
    plt.tight_layout(pad=0)
    plt.show()

# %%
generate_wordcloud(text, mask)
